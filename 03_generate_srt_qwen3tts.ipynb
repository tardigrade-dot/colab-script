# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #### Qwen3-ForcedAligner-0.6B
# #### Qwen3-ASR-1.7B

# %%
# !pip install -U qwen-asr
# !pip install wetext

# %%
import torch
from qwen_asr import Qwen3ASRModel

device = "cpu" #cuda:0
model = Qwen3ASRModel.from_pretrained(
    "/Volumes/sw/pretrained_models/Qwen3-ASR-1.7B",
    dtype=torch.bfloat16,
    device_map=device,
    # attn_implementation="flash_attention_2",
    max_inference_batch_size=32, # Batch size limit for inference. -1 means unlimited. Smaller values can help avoid OOM.
    max_new_tokens=256, # Maximum number of tokens to generate. Set a larger value for long audio input.
)

results = model.transcribe(
    audio="/Users/larry/github.com/tardigrade-dot/colab-script2/data_src/tianchaoyaoyuan2-7_3.wav",
    language="Chinese", # set "English" to force the language
)

print(results[0].language)
print(results[0].text)
# Out:
# Loading checkpoint shards: 100%|██████████| 2/2 [00:00<00:00,  8.17it/s]
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Chinese
# 西方与东方，文明与野蛮，西方文明征服东方野蛮的二元对立话语模式，根本上决定了西方现代性的世界秩序想象。要批判这种文化意识形态，必须追溯到启蒙观念本身。霍克海默和阿多尔诺在《启蒙辩证法》中明确指出，启蒙哲学本质上具有一种以支配和统治为目的主人的精神，并带有极权主义性质。启蒙神话中的理性与文明崇拜本身就已经包含着某种同一性，暴政在历史过程中必然最终堕入野蛮。尼采批判启蒙理性主义最终导致虚无主义，其意也在于此。西方与东方，文明与野蛮的二元对立思维模式，以及西方文明征服东方野蛮的暴力想象，都根植于现代性的思想资源——启蒙哲学中。西方现代性的秘密，包括它所有的成就与灾难，文明与野蛮，都必须追溯到启蒙哲学。启蒙思想为西方现代建构文化身份与他者提供了理论基础，它将自身认同为文明，将所有非西方世界排斥为野蛮，东方这一思想，确认了西方文化的同一性整体，也确定了西方与非西方的关系，并设定了西方现代扩张的观念模式，使殖民主义

# %%
results[0].text
# Out:
# '西方西方与东方，西方，西方与东方西方与东方与西方，西方与野蛮西方与东方。西方与东方。西方与东方。西方与 西方与东方， 东方与东方。东方东方 西西方与东方与 战东方与东方与   � 与东方 东方与东方与东方与东方。西方东方 东方与西方与 与东方与东方与 东方 东方与野  东方与东方与东方 东方与东方与东方与东方与东方与东方与东方与东方与东方与东方与东方与东方与东方与  东方与东方与东方与东方与东方与东方东方与东方与东方与   与东方 与东方与东方与东方与东方与东方与    与东方与东方与与东方 与东方与东方与东方与东方与东方与东方与东方与东方东方与与 与    与东方与东方与东方与东方与东方与东方与东方  东方与东方与   符与东方与东方与东方 与 与·于东方与东方与东方与东方与东方与东方与东方与  东方与东方与东方'
