# %% [markdown]
# <a href="https://colab.research.google.com/github/tardigrade-dot/colab-script/blob/main/05_generate_mp4_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# use Remotion create video

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/tardigrade-dot/audiobook-video

# %%
import os
os.chdir('/content/audiobook-video')
# !npm install

# %%
# !node /content/audiobook-video/render-all.js \
  /content/drive/MyDrive/wenhuaquanliyuguojia \
  --title "文化、权力与国家：1900—1942、年的华北农村 [美]杜赞奇" \
  --fps 5

# %%
# !node audiobook-video/render-single.js \
/content/drive/MyDrive/wenhuaquanliyuguojia/wenhuaquanliyuguojia-0_0.wav \
/content/drive/MyDrive/wenhuaquanliyuguojia/wenhuaquanliyuguojia-0_0.srt \
test-video \
--title "文化、权力与国家：1900—1942、年的华北农村 [美]杜赞奇"
